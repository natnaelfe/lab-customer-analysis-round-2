# %%
import pandas as pd
import numpy as np
import math

# %%
df1 = pd.read_csv('marketing_customer_analysis.csv')

# %%
df1
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %% [markdown]
# # 1. Show the dataframe shape

# %%
df1.shape
# Out:
# (10910, 26)

# %% [markdown]
# # 2. Standardize header names

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
df1.columns = [df1.columns[i].lower().replace(' ', '_') for i in range(len(df1.columns)) ]

# %%
df1.columns
# Out:
# Index(['unnamed:_0', 'customer', 'state', 'customer_lifetime_value',
#        'response', 'coverage', 'education', 'effective_to_date',
#        'employmentstatus', 'gender', 'income', 'location_code',
#        'marital_status', 'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size',
#        'vehicle_type'],
#       dtype='object')

# %%
df1 = df1.rename(columns={'unnamed:_0':'unnamed: 0', "employmentstatus": "employment_status"})

# %%
df1.columns
# Out:
# Index(['unnamed: 0', 'customer', 'state', 'customer_lifetime_value',
#        'response', 'coverage', 'education', 'effective_to_date',
#        'employment_status', 'gender', 'income', 'location_code',
#        'marital_status', 'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size',
#        'vehicle_type'],
#       dtype='object')

# %% [markdown]
# # 3. Which columns are numerical?

# %%
df1.dtypes
# Out:
# unnamed: 0                         int64
# customer                          object
# state                             object
# customer_lifetime_value          float64
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employment_status                 object
# gender                            object
# income                             int64
# location_code                     object
# marital_status                    object
# monthly_premium_auto               int64
# months_since_last_claim          float64
# months_since_policy_inception      int64
# number_of_open_complaints        float64
# number_of_policies                 int64
# policy_type                       object
# policy                            object
# renew_offer_type                  object
# sales_channel                     object
# total_claim_amount               float64
# ...

# %%
numerical_columns = df1.select_dtypes(include=['int', 'float']).columns
num_numerical_columns = len(numerical_columns)

# %%
print(f"Number of numerical columns: {num_numerical_columns}")
# Out:
# Number of numerical columns: 9

# %% [markdown]
# # 4. Which columns are categorical?

# %%
df1.dtypes
# Out:
# unnamed: 0                         int64
# customer                          object
# state                             object
# customer_lifetime_value          float64
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employment_status                 object
# gender                            object
# income                             int64
# location_code                     object
# marital_status                    object
# monthly_premium_auto               int64
# months_since_last_claim          float64
# months_since_policy_inception      int64
# number_of_open_complaints        float64
# number_of_policies                 int64
# policy_type                       object
# policy                            object
# renew_offer_type                  object
# sales_channel                     object
# total_claim_amount               float64
# ...

# %%
categorical_columns = df1.select_dtypes(include=['object']).columns
num_categorical_columns = len(categorical_columns)

# %%
print(f"Number of categorical columns: {num_categorical_columns}")
# Out:
# Number of categorical columns: 17

# %% [markdown]
# # 5. Check and deal with NaN values.

# %%
df1
# Out:
#        unnamed: 0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective_to_date employment_status gender  ...  \
# ...

# %%
df1.isnull().sum()
# Out:
# unnamed: 0                          0
# customer                            0
# state                             631
# customer_lifetime_value             0
# response                          631
# coverage                            0
# education                           0
# effective_to_date                   0
# employment_status                   0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim           633
# months_since_policy_inception       0
# number_of_open_complaints         633
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                     622
# vehicle_size                      622
# ...

# %%
df1.fillna("n/a", inplace=True) # Replace NaN values with "n/a"

# %%
print("Number of NaN values:", df1.isnull().sum().sum())
# Out:
# Number of NaN values: 0

# %% [markdown]
# # 6. Datetime format

# %% [markdown]
# Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, consider only January and February.

# %%
df1["effective_to_date"] = pd.to_datetime(df1["effective_to_date"]) # Convert date column to datetime format

# %%
df1["month"] = df1["effective_to_date"].dt.month # Extract month from date column

# %%
mask_1 = (df1["month"] == 1) | (df1["month"] == 2) | (df1["month"] == 3)
first_quarter_data = df1[mask_1]

# %%
count_1 = mask_1.sum()

# %%
count_1
# Out:
# 10910

# %%
df1.describe()
# Out:
#          unnamed: 0  customer_lifetime_value        income  \
# count  10910.000000             10910.000000  10910.000000
# mean    5454.500000              8018.241094  37536.284785
# std     3149.590053              6885.081434  30359.195670
# min        0.000000              1898.007675      0.000000
# 25%     2727.250000              4014.453113      0.000000
# 50%     5454.500000              5771.147235  33813.500000
# 75%     8181.750000              8992.779137  62250.750000
# max    10909.000000             83325.381190  99981.000000
#
#        monthly_premium_auto  months_since_policy_inception  \
# count          10910.000000                   10910.000000
# mean              93.196059                      48.091934
# std               34.442532                      27.940675
# min               61.000000                       0.000000
# 25%               68.000000                      24.000000
# 50%               83.000000                      48.000000
# ...

# %%
mask_2 = (df1["month"] >= 4) & (df1["month"] <= 12) # Filter data to show only April to December
apr_dec_data = df1[mask_2]

# %%
count_2 = mask_2.sum()

# %%
count_2
# Out:
# 0
